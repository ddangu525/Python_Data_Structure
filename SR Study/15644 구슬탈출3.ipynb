# %% [markdown]
# #### 문제
# 스타트링크에서 판매하는 어린이용 장난감 중에서 가장 인기가 많은 제품은 구슬 탈출이다.
# 구슬 탈출은 직사각형 보드에 빨간 구슬과 파란 구슬을 하나씩 넣은 다음, 빨간 구슬을 구멍을 통해 빼내는 게임이다.
#
# 보드의 세로 크기는 N, 가로 크기는 M이고, 편의상 1×1크기의 칸으로 나누어져 있다.
# 가장 바깥 행과 열은 모두 막혀져 있고, 보드에는 구멍이 하나 있다.
# 빨간 구슬과 파란 구슬의 크기는 보드에서 1×1크기의 칸을 가득 채우는 사이즈이고, 각각 하나씩 들어가 있다.
# 게임의 목표는 빨간 구슬을 구멍을 통해서 빼내는 것이다. 이때, 파란 구슬이 구멍에 들어가면 안된다.
#
# 이때, 구슬을 손으로 건드릴 수는 없고, 중력을 이용해서 이리 저리 굴려야 한다.
# 왼쪽으로 기울이기, 오른쪽으로 기울이기, 위쪽으로 기울이기, 아래쪽으로 기울이기와 같은 네 가지 동작이 가능하다.
#
# 각각의 동작에서 공은 동시에 움직인다. 빨간 구슬이 구멍에 빠지면 성공이지만, 파란 구슬이 구멍에 빠지면 실패이다.
# 빨간 구슬과 파란 구슬이 동시에 구멍에 빠져도 실패이다. 빨간 구슬과 파란 구슬은 동시에 같은 칸에 있을 수 없다.
# 또, 빨간 구슬과 파란 구슬의 크기는 한 칸을 모두 차지한다. 기울이는 동작을 그만하는 것은 더 이상 구슬이 움직이지 않을 때 까지이다.
#
# 보드의 상태가 주어졌을 때, 최소 몇 번 만에 빨간 구슬을 구멍을 통해 빼낼 수 있는지, 또 어떻게 기울여야 하는지 구하는 프로그램을 작성하시오.
#
# #### 입력
# 첫 번째 줄에는 보드의 세로, 가로 크기를 의미하는 두 정수 N, M (3 ≤ N, M ≤ 10)이 주어진다.
# 다음 N개의 줄에 보드의 모양을 나타내는 길이 M의 문자열이 주어진다. 이 문자열은 '.', '#', 'O', 'R', 'B' 로 이루어져 있다.
# '.'은 빈 칸을 의미하고, '#'은 공이 이동할 수 없는 장애물 또는 벽을 의미하며, 'O'는 구멍의 위치를 의미한다.
# 'R'은 빨간 구슬의 위치, 'B'는 파란 구슬의 위치이다.
#
# 입력되는 모든 보드의 가장자리에는 모두 '#'이 있다. 구멍의 개수는 한 개 이며, 빨간 구슬과 파란 구슬은 항상 1개가 주어진다.
#
# #### 출력
# 첫째 줄에 최소 몇 번 만에 빨간 구슬을 구멍을 통해 빼낼 수 있는지, 둘째 줄에 어떻게 기울여야 하는지 순서대로 출력한다.
# 왼쪽으로 기울이기는 'L', 오른쪽으로 기울이기는 'R', 위로 기울이기는 'U', 아래로 기울이기는 'D'로 출력하며, 공백없이 한 줄에 모두 출력한다.
# 가능한 방법이 여러 가지면, 아무거나 출력한다.
#
# 만약, 10번 이하로 움직여서 빨간 구슬을 구멍을 통해 빼낼 수 없으면 -1을 출력한다.

# %% [markdown]
# ### ------------------------------------------------------------------------------

# %% [markdown]
# 최소 조작으로 빨간구슬을 빼내야 함.. 파란 구슬은 구멍으로 빠지면 안됨..  최대 10번..
# \# 장애물, 벽 / . 빈칸
# 시간 복잡도.. 4^10 \* ....
# 1. 왼쪽으로 기울이기: x좌표만 감소.
# 2. 오른쪽으로 기울이기: x좌표 증가
# 3. 위쪽으로 기울이기: y좌표 감소
# 4. 아래쪽으로 기울이기: y좌표 증가
#
# 두 구슬이 같이 움직일 때, 먼저 벽에 닿는 구슬을 먼저 처리해주기.
# 이동시킬때 구멍에 빠지는지도 확인해야...
# 가지치기를 어떻게??
# 1. 현 위치에서 하나라도 움직일때만 큐에 추가.
# 2. 같은 줄에서 왔다갔다 하지 않도록 한다..
# 예를들어 어느 시점에서 왼쪽으로 보낸 후에 다시 오른쪽으로 보내는 경우가 없도록.
# 즉 이전에 왼쪽으로 갔다면 지금은 위나, 아래로 가는 경우만 생각.
# 경로 출력은 어떤식으로 할까..?
# 구슬이 빠지는것 확인은.. 구슬의 좌표 정보를 None으로 해서 빨간구슬만 None이되면 빼진것.. 둘 다 None이면 또 실패고..
# 최소값, 경로 출력..

# %%
# import sys
# input = sys.stdin.readline
from collections import deque

# input, 보드생성, 구슬, 구멍 좌표 저장.
N, M = map(int, input().split())
board = []
red = blue = hole = None
for y in range(N):
    row = list(input().rstrip())
    for x in range(M):
        if row[x] == 'R':
            red = [x,y]
        elif row[x] == 'B':
            blue = [x,y]
        elif row[x] == 'O':
            hole = x,y
        
# 1. 왼쪽으로 기울이기. red, blue y좌표가 같으면 x좌표가 작은애부터 먼저 이동시키기.
def left():
    rx = red[0]
    bx = blue[0]
    
    # 1. y좌표가 같은경우.. x좌표가 작은애부터 왼쪽으로 이동시키기.
    if red[1]==blue[1]: 
        y = red[1]
        # 1-1. 빨간구슬이 더 왼쪽에. 먼저이동시켜주기
        if red[0]<blue[0]:
            # 1-1-1. 빨간구슬
            for x in range(rx-1, -1, -1):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][rx] = '.'
                    red = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 오른쪽에 빨간 구슬이 멈춤.
                    board[y][x+1] = 'R'
                    # 원래위치는 빈공간으로..
                    board[y][rx] = '.'
                    # 빨간구슬 x좌표 바꿔주기.
                    red[0] = x+1
                    break
                # 끝까지 벽이 없으면..
                elif x == 0 and board[y][x] == '.':
                    board[y][0] = 'R'
                    board[y][rx] = '.'
                    red[0] = 0
            # 1-1-2. 그 다음 파란구슬 이동. 빨간구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for x in range(bx-1, rx, -1): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][bx] = '.'
                    blue = None
                    break
                if board[y][x] == '#':
                    board[y][x+1] = 'B'
                    board[y][bx] = '.'
                    blue[0] = x+1
                    break
                # rx+1위치까지 벽이 없다면. 얘는 빨간구슬 바로 오른쪽까지..
                elif x == rx+1 and board[y][x] == '.':
                    # red가 구멍에 빠졌을때.. 얘도 구멍에 빠짐.
                    if red is None:
                        blue = None
                        break
                    board[y][red[0]+1] = 'B'
                    board[y][ry] = '.'
                    blue[0] = red[0]+1
        
        # 1-2. 파란구슬이 왼쪽..빨간구슬은 bx까지만 검사.
        else:
            # 파란구슬 먼저.
            for x in range(bx-1, -1, -1):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][bx] = '.'
                    blue = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 오른쪽에 파란 구슬이 멈춤.
                    board[y][x+1] = 'B'
                    # 원래위치는 빈공간으로..
                    board[y][bx] = '.'
                    # 빨간구슬 x좌표 바꿔주기.
                    blue[0] = x+1
                    break
                # 끝까지 벽이 없으면..
                elif x == 0 and board[y][x] == '.':
                    board[y][0] = 'B'
                    board[y][bx] = '.'
                    blue[0] = 0
            # 그 다음 빨간구슬 이동. 파란구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for x in range(rx-1, bx, -1): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][rx] = '.'
                    red = None
                    break
                if board[y][x] == '#':
                    board[y][x+1] = 'R'
                    board[y][rx] = '.'
                    red[0] = x+1
                    break
                # rx+1위치까지 벽이 없다면. 얘는 빨간구슬 바로 오른쪽까지..
                elif x == bx+1 and board[y][x] == '.':
                    # red가 구멍에 빠졌을때.. 얘도 구멍에 빠짐.
                    if blue is None:
                        red = None
                        break
                    board[y][blue[0]+1] = 'B'
                    board[y][rx] = '.'
                    red[0] = blue[0]+1
    
    # y좌표가 다른경우 각각 이동시켜줌...
    else:
        # 각자 해주면 된다.
        # 빨간구슬 먼저.
        for x in range(rx-1, -1, -1):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[y][rx] = '.'
                red = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 빨간 구슬이 멈춤.
                board[y][x+1] = 'R'
                # 원래위치는 빈공간으로..
                board[y][rx] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                red[0] = x+1
                break
            # 끝까지 벽이 없으면..
            elif x == 0 and board[y][x] == '.':
                board[y][0] = 'R'
                board[y][rx] = '.'
                red[0] = 0
        # 그 다음 파란구슬
        for x in range(bx-1, -1, -1):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[y][bx] = '.'
                blue = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 파란 구슬이 멈춤.
                board[y][x+1] = 'B'
                # 원래위치는 빈공간으로..
                board[y][bx] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                blue[0] = x+1
                break
            # 끝까지 벽이 없으면..
            elif x == 0 and board[y][x] == '.':
                board[y][0] = 'B'
                board[y][bx] = '.'
                blue[0] = 0

# 2
def right():
    rx = red[0]
    bx = blue[0]
    
    # 1. y좌표가 같은경우.. x좌표가 큰애부터 오른쪽으로 이동시키기.
    if red[1]==blue[1]: 
        y = red[1]
        # 1-1. 빨간구슬이 더 오른쪽에. 먼저이동시켜주기
        if red[0]>blue[0]:
            # 1-1-1. 빨간구슬
            for x in range(rx+1, M):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][rx] = '.'
                    red = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 왼쪽에 빨간 구슬이 멈춤.
                    board[y][x-1] = 'R'
                    # 원래위치는 빈공간으로..
                    board[y][rx] = '.'
                    # 빨간구슬 x좌표 바꿔주기.
                    red[0] = x-1
                    break
                # 끝까지 벽이 없으면..
                elif x == M-1 and board[y][x] == '.':
                    board[y][M-1] = 'R'
                    board[y][rx] = '.'
                    red[0] = M-1
            # 1-1-2. 그 다음 파란구슬 이동. 빨간구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for x in range(bx+1, rx): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][bx] = '.'
                    blue = None
                    break
                if board[y][x] == '#':
                    board[y][x-1] = 'B'
                    board[y][bx] = '.'
                    blue[0] = x-1
                    break
                # rx+1위치까지 벽이 없다면. 얘는 빨간구슬 바로 오른쪽까지..
                elif x == rx-1 and board[y][x] == '.':
                    # 구멍에 같이빠짐..
                    if red is None:
                        blue = None
                        break
                    board[y][red[0]-1] = 'B'
                    board[y][ry] = '.'
                    blue[0] = red[0]-1
        
        # 1-2. 파란구슬이 오른쪽..빨간구슬은 bx까지만 검사.
        else:
            # 파란구슬 먼저.
            for x in range(bx+1, M):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][bx] = '.'
                    blue = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 왼쪽에 파란 구슬이 멈춤.
                    board[y][x-1] = 'B'
                    # 원래위치는 빈공간으로..
                    board[y][bx] = '.'
                    # 빨간구슬 x좌표 바꿔주기.
                    blue[0] = x-1
                    break
                # 끝까지 벽이 없으면..
                elif x == M-1 and board[y][x] == '.':
                    board[y][M-1] = 'B'
                    board[y][bx] = '.'
                    blue[0] = M-1
            # 그 다음 빨간구슬 이동. 파란구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for x in range(rx+1, bx): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][rx] = '.'
                    red = None
                    break
                if board[y][x] == '#':
                    board[y][x-1] = 'R'
                    board[y][rx] = '.'
                    red[0] = x-1
                    break
                # bx-1위치까지 벽이 없다면. 얘는 파란구슬 바로 왼쪽까지..
                elif x == bx-1 and board[y][x] == '.':
                    if blue is None:
                        red = None
                        break
                    board[y][blue[0]-1] = 'B'
                    board[y][rx] = '.'
                    red[0] = blue[0]+1
    
    # y좌표가 다른경우 각각 이동시켜줌...
    else:
        # 각자 해주면 된다.
        # 빨간구슬 먼저.
        for x in range(rx+1, M):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[y][rx] = '.'
                red = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 빨간 구슬이 멈춤.
                board[y][x-1] = 'R'
                # 원래위치는 빈공간으로..
                board[y][rx] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                red[0] = x-1
                break
            # 끝까지 벽이 없으면..
            elif x == M-1 and board[y][x] == '.':
                board[y][M-1] = 'R'
                board[y][rx] = '.'
                red[0] = M-1
        # 그 다음 파란구슬
        for x in range(bx+1, M):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[y][bx] = '.'
                blue = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 파란 구슬이 멈춤.
                board[y][x-1] = 'B'
                # 원래위치는 빈공간으로..
                board[y][bx] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                blue[0] = x-1
                break
            # 끝까지 벽이 없으면..
            elif x == M-1 and board[y][x] == '.':
                board[y][M-1] = 'B'
                board[y][bx] = '.'
                blue[0] = M-1
                
# 3. 위로.. 왼쪽이랑 비슷.. 얘는 y좌표 비교..
def up():
    ry = red[1]
    by = blue[1]
    
    # 1. x좌표가 같은경우.. y좌표가 작은애부터 위쪽으로 이동시키기.
    if red[0]==blue[0]: 
        x = red[0]
        # 1-1. 빨간구슬이 더 위쪽에. 먼저이동시켜주기
        if ry<by:
            # 1-1-1. 빨간구슬
            for y in range(ry-1, -1, -1):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[ry][x] = '.'
                    red = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 아래쪽에 빨간 구슬이 멈춤.
                    board[y+1][x] = 'R'
                    # 원래위치는 빈공간으로..
                    board[ry][x] = '.'
                    # 빨간구슬 y좌표 바꿔주기.
                    red[1] = y+1
                    break
                # 끝까지 벽이 없으면..
                elif y == 0 and board[y][x] == '.':
                    board[0][x] = 'R'
                    board[ry][x] = '.'
                    red[1] = 0
            # 1-1-2. 그 다음 파란구슬 이동. 빨간구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for y in range(by-1, ry, -1): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[by][x] = '.'
                    blue = None
                    break
                if board[y][x] == '#':
                    board[y+1][x] = 'B'
                    board[by][x] = '.'
                    blue[1] = y+1
                    break
                # rx+1위치까지 벽이 없다면. 얘는 빨간구슬 바로 오른쪽까지..
                elif y == rx+1 and board[y][x] == '.':
                    # red가 구멍에 빠졌을때.. 얘도 구멍에 빠짐.
                    if red is None:
                        blue = None
                        break
                    board[red[1]+1][x] = 'B'
                    board[ry][x] = '.'
                    blue[1] = red[1]+1
        
        # 1-2. 파란구슬이 왼쪽..빨간구슬은 bx까지만 검사.
        else:
            # 파란구슬 먼저.
            for y in range(by-1, -1, -1):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[by][x] = '.'
                    blue = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 아래쪽에 파란 구슬이 멈춤.
                    board[y+1][x] = 'B'
                    # 원래위치는 빈공간으로..
                    board[by][x] = '.'
                    # 파란구슬 y좌표 바꿔주기.
                    blue[1] = y+1
                    break
                # 끝까지 벽이 없으면..
                elif y == 0 and board[y][x] == '.':
                    board[0][x] = 'B'
                    board[by][x] = '.'
                    blue[1] = 0
            # 그 다음 빨간구슬 이동. 파란구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for y in range(ry-1, by, -1): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[ry][x] = '.'
                    red = None
                    break
                if board[y][x] == '#':
                    board[y+1][x] = 'R'
                    board[ry][x] = '.'
                    red[1] = y+1
                    break
                # ry+1위치까지 벽이 없다면. 얘는 빨간구슬 바로 오른쪽까지..
                elif y == by+1 and board[y][x] == '.':
                    # red가 구멍에 빠졌을때.. 얘도 구멍에 빠짐.
                    if blue is None:
                        red = None
                        break
                    board[blue[1]+1][x] = 'B'
                    board[ry][x] = '.'
                    red[1] = blue[1]+1
    
    # y좌표가 다른경우 각각 이동시켜줌...
    else:
        # 각자 해주면 된다.
        # 빨간구슬 먼저.
        for y in range(ry-1, -1, -1):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[ry][x] = '.'
                red = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 빨간 구슬이 멈춤.
                board[y+1][x] = 'R'
                # 원래위치는 빈공간으로..
                board[ry][x] = '.'
                # 빨간구슬 y좌표 바꿔주기.
                red[1] = y+1
                break
            # 끝까지 벽이 없으면..
            elif y == 0 and board[y][x] == '.':
                board[0][x] = 'R'
                board[ry][x] = '.'
                red[1] = 0
        # 그 다음 파란구슬
        for x in range(bx-1, -1, -1):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[by][x] = '.'
                blue = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 파란 구슬이 멈춤.
                board[y+1][x] = 'B'
                # 원래위치는 빈공간으로..
                board[by][x] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                blue[1] = y+1
                break
            # 끝까지 벽이 없으면..
            elif y == 0 and board[y][x] == '.':
                board[0][x] = 'B'
                board[by][x] = '.'
                blue[1] = 0

# 4. 얘는 오른쪽이랑 비슷..
def down():
    ry = red[1]
    by = blue[1]
    
    # 1. x좌표가 같은경우.. y좌표가 큰애부터 아래쪽으로 이동시키기.
    if red[0]==blue[0]: 
        x = red[0]
        # 1-1. 빨간구슬이 더 아래쪽에. 먼저이동시켜주기
        if red[1]>blue[1]:
            # 1-1-1. 빨간구슬
            for y in range(ry+1, N):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[ry][x] = '.'
                    red = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 위쪽에 빨간 구슬이 멈춤.
                    board[y-1][x] = 'R'
                    # 원래위치는 빈공간으로..
                    board[ry][x] = '.'
                    # 빨간구슬 y좌표 바꿔주기.
                    red[1] = y-1
                    break
                # 끝까지 벽이 없으면..
                elif y == N-1 and board[y][x] == '.':
                    board[N-1][x] = 'R'
                    board[ry][x] = '.'
                    red[1] = N-1
            # 1-1-2. 그 다음 파란구슬 이동. 빨간구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for y in range(by+1, ry): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[by][b] = '.'
                    blue = None
                    break
                if board[y][x] == '#':
                    board[y-1][x] = 'B'
                    board[by][x] = '.'
                    blue[1] = y-1
                    break
                # rx+1위치까지 벽이 없다면. 얘는 빨간구슬 바로 위쪽까지..
                elif y == ry-1 and board[y][x] == '.':
                    # 구멍에 같이빠짐..
                    if red is None:
                        blue = None
                        break
                    board[red[1]-1][x] = 'B'
                    board[ry][x] = '.'
                    blue[1] = red[1]-1
        
        # 1-2. 파란구슬이 아래쪽..빨간구슬은 bx까지만 검사.
        else:
            # 파란구슬 먼저.
            for y in range(by+1, N):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[by][x] = '.'
                    blue = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 왼쪽에 파란 구슬이 멈춤.
                    board[y-1][x] = 'B'
                    # 원래위치는 빈공간으로..
                    board[by][x] = '.'
                    # 빨간구슬 y좌표 바꿔주기.
                    blue[1] = y-1
                    break
                # 끝까지 벽이 없으면..
                elif y == N-1 and board[y][x] == '.':
                    board[N-1][x] = 'B'
                    board[by][x] = '.'
                    blue[1] = N-1
            # 그 다음 빨간구슬 이동. 파란구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for y in range(ry+1, by): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[ry][x] = '.'
                    red = None
                    break
                if board[y][x] == '#':
                    board[y-1][x] = 'R'
                    board[ry][x] = '.'
                    red[1] = y-1
                    break
                # bx-1위치까지 벽이 없다면. 얘는 파란구슬 바로 왼쪽까지..
                elif y == by-1 and board[y][x] == '.':
                    if blue is None:
                        red = None
                        break
                    board[blue[1]-1][y] = 'B'
                    board[ry][x] = '.'
                    red[1] = blue[1]+1
    
    # y좌표가 다른경우 각각 이동시켜줌...
    else:
        # 각자 해주면 된다.
        # 빨간구슬 먼저.
        for y in range(ry+1, N):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[ry][x] = '.'
                red = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 빨간 구슬이 멈춤.
                board[y-1][x] = 'R'
                # 원래위치는 빈공간으로..
                board[ry][x] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                red[1] = y-1
                break
            # 끝까지 벽이 없으면..
            elif y == N-1 and board[y][x] == '.':
                board[N-1][x] = 'R'
                board[ry][x] = '.'
                red[1] = N-1
        # 그 다음 파란구슬
        for y in range(by+1, N):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[by][x] = '.'
                blue = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 파란 구슬이 멈춤.
                board[y-1][x] = 'B'
                # 원래위치는 빈공간으로..
                board[by][x] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                blue[1] = y-1
                break
            # 끝까지 벽이 없으면..
            elif y == N-1 and board[y][x] == '.':
                board[N-1][x] = 'B'
                board[by][x] = '.'
                blue[1] = N-1


# 다 만들었다 치고...
# 큐에 어떻게 넣을까... 경로로...
q = deque()
q.append('L')
q.append('R')
q.append('U')
q.append('D')

while q:
    
    path = q.popleft()[-1]

# %%
from collections import deque
q = deque()
q.append('L')
q
# Out:
# deque(['L'])

# %%
q.append('R')
q
# Out:
# deque(['L', 'R'])

# %%
q.popleft()
# Out:
# 'L'

# %% [markdown]
# 밀어야할까..  일단 옮기는 함수를 하나로 할 수 있을 것 같다....
# 함수의 파라미터로는 현재 구슬들의 위치(rx,ry,bx,by), 그리고 움직일 방향..(U/D/L/R) 이렇게만 받으면 될까?
# 큐에는 방향만 말고 현재까지 이동경로로 적자... 처음에는 (rx,ry,bx,by,'L') 이런식으로 4개..
# 그 다음에는 (rx,ry,bx,by,'LU') 이런식으로
# level별로 bfs하자..
# 그리고 return 값으로는 이동 후의 구슬들 위치.. (rnx, rny, bnx, bny)
#
# 그래서 bfs 하다가 빨간애만 빠질 수 있는 경우가 생기면 그 경로의 길이, 경로 출력하고 바로 종료.
# 10번 넘어가면 -1출력..

# %%
# red좌표, blue좌표, 이동방향을 받아서 새로운 좌표 반환.. 구멍에 빠진다면 None을 반환..
def move(red, blue, d):
    rx, ry = red
    bx, by = blue
    
    # 1. y좌표가 같은경우.. x좌표가 작은애부터 왼쪽으로 이동시키기.
    if red[1]==blue[1]: 
        y = red[1]
        # 1-1. 빨간구슬이 더 왼쪽에. 먼저이동시켜주기
        if red[0]<blue[0]:
            # 1-1-1. 빨간구슬
            for x in range(rx-1, -1, -1):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][rx] = '.'
                    red = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 오른쪽에 빨간 구슬이 멈춤.
                    board[y][x+1] = 'R'
                    # 원래위치는 빈공간으로..
                    board[y][rx] = '.'
                    # 빨간구슬 x좌표 바꿔주기.
                    red[0] = x+1
                    break
                # 끝까지 벽이 없으면..
                elif x == 0 and board[y][x] == '.':
                    board[y][0] = 'R'
                    board[y][rx] = '.'
                    red[0] = 0
            # 1-1-2. 그 다음 파란구슬 이동. 빨간구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for x in range(bx-1, rx, -1): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][bx] = '.'
                    blue = None
                    break
                if board[y][x] == '#':
                    board[y][x+1] = 'B'
                    board[y][bx] = '.'
                    blue[0] = x+1
                    break
                # rx+1위치까지 벽이 없다면. 얘는 빨간구슬 바로 오른쪽까지..
                elif x == rx+1 and board[y][x] == '.':
                    # red가 구멍에 빠졌을때.. 얘도 구멍에 빠짐.
                    if red is None:
                        blue = None
                        break
                    board[y][red[0]+1] = 'B'
                    board[y][ry] = '.'
                    blue[0] = red[0]+1
        
        # 1-2. 파란구슬이 왼쪽..빨간구슬은 bx까지만 검사.
        else:
            # 파란구슬 먼저.
            for x in range(bx-1, -1, -1):
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][bx] = '.'
                    blue = None
                    break
                # 벽을 만나면.
                if board[y][x] == '#':
                    # 벽 오른쪽에 파란 구슬이 멈춤.
                    board[y][x+1] = 'B'
                    # 원래위치는 빈공간으로..
                    board[y][bx] = '.'
                    # 빨간구슬 x좌표 바꿔주기.
                    blue[0] = x+1
                    break
                # 끝까지 벽이 없으면..
                elif x == 0 and board[y][x] == '.':
                    board[y][0] = 'B'
                    board[y][bx] = '.'
                    blue[0] = 0
            # 그 다음 빨간구슬 이동. 파란구슬이 원래 있던 위치까지만 검사.
            # 이 때 빨간구슬과 파란구슬이 원래 붙어있었고 이동이 안되면 파란구슬 위치도 그대로 유지되나?
            for x in range(rx-1, bx, -1): 
                # 구멍에 빠짐!
                if board[y][x] == 'O':
                    board[y][rx] = '.'
                    red = None
                    break
                if board[y][x] == '#':
                    board[y][x+1] = 'R'
                    board[y][rx] = '.'
                    red[0] = x+1
                    break
                # rx+1위치까지 벽이 없다면. 얘는 빨간구슬 바로 오른쪽까지..
                elif x == bx+1 and board[y][x] == '.':
                    # red가 구멍에 빠졌을때.. 얘도 구멍에 빠짐.
                    if blue is None:
                        red = None
                        break
                    board[y][blue[0]+1] = 'B'
                    board[y][rx] = '.'
                    red[0] = blue[0]+1
    
    # y좌표가 다른경우 각각 이동시켜줌...
    else:
        # 각자 해주면 된다.
        # 빨간구슬 먼저.
        for x in range(rx-1, -1, -1):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[y][rx] = '.'
                red = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 빨간 구슬이 멈춤.
                board[y][x+1] = 'R'
                # 원래위치는 빈공간으로..
                board[y][rx] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                red[0] = x+1
                break
            # 끝까지 벽이 없으면..
            elif x == 0 and board[y][x] == '.':
                board[y][0] = 'R'
                board[y][rx] = '.'
                red[0] = 0
        # 그 다음 파란구슬
        for x in range(bx-1, -1, -1):
            # 구멍에 빠짐!
            if board[y][x] == 'O':
                board[y][bx] = '.'
                blue = None
                break
            # 벽을 만나면.
            if board[y][x] == '#':
                # 벽 오른쪽에 파란 구슬이 멈춤.
                board[y][x+1] = 'B'
                # 원래위치는 빈공간으로..
                board[y][bx] = '.'
                # 빨간구슬 x좌표 바꿔주기.
                blue[0] = x+1
                break
            # 끝까지 벽이 없으면..
            elif x == 0 and board[y][x] == '.':
                board[y][0] = 'B'
                board[y][bx] = '.'
                blue[0] = 0

# %%
# import sys
# input = sys.stdin.readline
from collections import deque

# input, 보드생성, 구슬, 구멍 좌표 저장.
N, M = map(int, input().split())
board = []
for y in range(N):
    row = list(input().rstrip())
    for x in range(M):
        if row[x] == 'R':
            red = x, y
        elif row[x] == 'B':
            blue = x, y
        elif row[x] == 'O':
            hole = x, y


###################### move함수만 구현 ######################
# red좌표, blue좌표, 이동방향을 받아서 새로운 좌표 반환.. 구멍에 빠진다면 None을 반환..
def move(red, blue, d):
    rx, ry = red
    bx, by = blue


# 큐 만들어서 bfs 돌리기.
q = deque()
q.append((red, blue, 'U'))
q.append((red, blue, 'D'))
q.append((red, blue, 'L'))
q.append((red, blue, 'R'))
# 최대 10번까지만 시도.
for t in range(1, 11):
    # 큐 전체에 대해 1번씩만 늘려가면서..q가 없어져도 ㄱㅊ
    for _ in range(len(q)):
        red, blue, path = q.popleft()
        d = path[-1]
        new_red, new_blue = move(rx, ry, bx, by, d)
        # 빨간색만 구멍에 빠진경우!  출력하고 종료!!
        if new_red is None and new_blue:
            print(t, path, sep="\n")
            exit()
        # 구슬들이 모두 남아있는 경우.. 새로 큐에 두 경우 추가..
        elif new_red and new_blue:
            # 방금 위나 아래로 이동했다면 다음엔 좌우 두 경우만 생각..
            if d in ('UD'):
                q.append((new_red, new_blue, path+'L'))
                q.append((new_red, new_blue, path+'R'))
            # 방금 왼쪽이나 오른쪽이었다면 다음에는 위아래만..
            else:
                q.append((new_red, new_blue, path+'U'))
                q.append((new_red, new_blue, path+'D'))
print(-1)
